# %%
import logging
logging.basicConfig()
logger = logging.getLogger("stlarm")
logger.setLevel(logging.INFO)

from stlarm import analyzer

# %%
STEP_KB_FILE = "../resources/step_nyc_foursquare_period_2_2_None_filtered_triples.nt"
CONVERTED_KB_FILE = "../resources/converted_nyc_foursquare_period_2_2_None_filtered_triples.nt"

# %%
kba = analyzer.KBAnalyzer()
step_kb = kba.analyse_kb(STEP_KB_FILE)
converted_kb = kba.analyse_kb(CONVERTED_KB_FILE)
# Out:
# INFO:stlarm.analyzer:Processing ../resources/step_nyc_foursquare_period_2_2_None_filtered_triples.nt
# INFO:stlarm.analyzer:[Done] amie.data.utils.KBsSummarizer
# INFO:stlarm.analyzer:Processing ../resources/converted_nyc_foursquare_period_2_2_None_filtered_triples.nt
# INFO:stlarm.analyzer:[Done] amie.data.utils.KBsSummarizer

# %%
step_kb.round(2)
# Out:
#                    Relation  Triples  Functionality  Inverse functionality  \
# 0              <hasEpisode>   431112           0.23                   0.08
# 1              <hasFeature>   151627           0.52                   1.00
# 2               <relatesTo>   106079           0.33                   0.71
# 3  <hasSemanticDescription>    53636           1.00                   0.00
# 4           <hasTrajectory>     4557           0.03                   1.00
# 5                     TOTAL   747011            NaN                    NaN
#
#    Variance  Inverse Variance  Number of subjects  Number of objects
# 0     10.49             48.10               98118              35460
# 1      1.06              0.00               79554             151627
# 2      0.01             13.59               35460              74997
# 3      0.00       11417580.95               53509                 33
# 4    696.97              0.00                 158               4557
# ...

# %%
converted_kb.round(2)
# Out:
#                    Relation  Triples  Functionality  Inverse functionality  \
# 0                  <before>   145598           0.21                   0.21
# 1            <withinRadius>   134710           0.23                   0.23
# 2        <withinTimeWindow>   115344           0.28                   0.28
# 3              <hasCheckin>    35460           0.13                   1.00
# 4                  <hasPOI>    35460           1.00                   0.12
# 5                 <hasTime>    35460           1.00                   0.00
# 6   <hasTrajectoryCategory>     4675           0.97                   0.00
# 7           <hasTrajectory>     4557           0.03                   1.00
# 8         <hasDayOfTheWeek>     4557           1.00                   0.00
# 9                <hasMonth>     4557           1.00                   0.00
# 10         <hasPOICategory>     4387           1.00                   0.00
# ...
